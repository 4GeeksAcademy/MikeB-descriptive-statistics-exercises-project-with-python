# %% [markdown]
# # Descriptive statistics problems

# %% [markdown]
# ### Exercise 1
#
# We will use NumPy to obtain information to describe statistically.
#
# - Generate an array of 100 elements following a normal distribution.
# - Generate an array of 100 elements following a chi-square distribution with 3 degrees of freedom.
# - Calculate the main metrics and statistical measures that best describe the two vectors.

# %%
# TODO
import random
import numpy as np
import matplotlib.pyplot as plt

distribArr = np.random.normal(size=100)
chisqrArr = np.random.chisquare(df=3, size=100)

plt.hist(distribArr, bins = 30, alpha = 0.5, density=True, label = "Normal Distribution")
plt.hist(chisqrArr, bins = 30, alpha = 0.5, density=True, label = "Chi-Square Distribution")
plt.legend()
plt.title('Descriptive Statistics')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %% [markdown]
# ### Exercise 2
#
# Write a Python program to calculate the standard deviation of the following data:
#
# ```py
# data = [4, 2, 5, 8, 6]
# ```

# %%
# TODO
import statistics as stats

data = [4, 2, 5, 8, 6]

total = 0
for i in range (len(data)):
    total += data[i]

mean = total / len(data)

sqrDiff = []
for i in range (len(data)):
    sqrDiff.append((data[i]-mean)**2)

sumSqrDiff = 0
for i in range (len(sqrDiff)):
    sumSqrDiff += sqrDiff[i]

stdDevCalc = (sumSqrDiff / len(data))**0.5
print(stdDevCalc)

# # With the Python build in functions comparison
# std = stats.stdev(data)
# print(std)
# Out:
# 2.0
# 2.23606797749979
